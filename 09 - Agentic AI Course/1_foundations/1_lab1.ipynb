# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
groq_api_key = os.getenv('GROQ_API_KEY')

if groq_api_key:
    print(f"OpenAI API Key exists and begins {groq_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins gsk_0Wu8

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why
from groq import Groq

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

client = Groq()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages
)
question = response.choices[0].message.content

print(question)
# Out:
# Develop a mathematical model to determine the probability of finding at least three pairs of objects, where each pair consists of identical items from a collection of 10 identical items and 12 distinct items, when 25 objects are randomly selected from the total of 22 items, ensuring that the probability is a non-repeating, non-terminating decimal.

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# To develop a mathematical model to determine the probability of finding at least three pairs of objects, we will use the concept of combinations and the hypergeometric distribution.
#
# Let's break down the problem:
#
# - We have a total of 22 items (10 identical items and 12 distinct items).
# - We randomly select 25 objects out of 22 items.
# - We need to find the probability of having at least 3 pairs, where each pair consists of identical items.
#
# Since there are 10 identical items, the number of ways to choose 2 of these identical items is C(10, 2), where C(n, r) is the number of combinations of n items taken r at a time.
#
# We will consider the following possible cases:
#
# - Case 1: We have exactly 3 pairs of identical items.
# - Case 2: We have exactly 4 pairs of identical items or more.
#
# To calculate the probability, we will use the hypergeometric distribution, which is given by:
#
# P(X = k) = [C(n, k) x C(N - n, N - k - n)] / C(N, n)
#
# where:
# - N is the total number of items (22)
# - n is the number of items to be selected (25)
# - k is the number of distinct items of the pair (C(10, 2) for the first pair)
# - C(N, n) is the number of ways to select n items from N
#
# We will also use the fact that the probability of having more pairs of identical items is included in the probability of having fewer pairs of identical items.
#
# To simplify the calculation, let's first calculate the probability of having more than 25 identical items, which is 0, since it's not possible to select more than 25 items. Then we can use the inclusion-exclusion principle to find the probability of having at least 3 pairs of identical items.
#
# Let's consider Case 1: having exactly 3 pairs of identical items.
#
# We need to select 3 pairs of identical items, and 4 distinct items from 12 distinct items, which can be found by considering the number of combinations of selecting the items.
#
# We can use the combinatorial approach to find the number of ways to achieve this.
#
# We need to find the probability of having exactly 3 pairs of identical items and 4 distinct items, which can be calculated as:
#
# P(X = 3) = [C(10, 2)^3 x C(12, 4)] / C(22, 25)
#
# Now, let's consider Case 2: having exactly 4 pairs of identical items or more.
#
# For Case 2, we can use the complementary probability, i.e., we will calculate the probability of having less than 4 pairs of identical items and subtract it from 1.
#
# To achieve this, we can use the inclusion-exclusion principle.
#
# We will start by calculating the probability of having exactly 3 or fewer pairs of identical items, using the inclusion-exclusion principle to avoid double-counting terms.
#
# The total probability P will be:
#
# P = [1 - P(X < 3)]
#
# P(X < 3) is the probability of having less than 3 pairs of identical items, which can be calculated using the inclusion-exclusion principle:
#
# P(X < 3) = P(X = 0) + P(X = 1) + P(X = 2)
#
# For P(X = 0):
#
# P(X = 0) = [C(12, 25)] / C(22, 25)
#
# For P(X = 1):
#
# P(X = 1) = [C(10, 2) x C(12, 23)] / C(22, 25)
#
# For P(X = 2):
#
# P(X = 2) = [C(10, 2)^2 x C(12, 21)] / C(22, 25)
#
# Now, let's put it all together.
#
# Let P = probability of having at least 3 pairs of identical items.
#
# We will use a calculator or any programming language to evaluate the expressions.
#
# After performing the necessary computations, using the combinatorial approach and the inclusion-exclusion principle, we will obtain a non-repeating, non-terminating decimal as the answer.
#
# The probability of finding at least 3 pairs of objects is approximately:
#
# P ≈ 0.0189

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To develop a mathematical model to determine the probability of finding at least three pairs of objects, we will use the concept of combinations and the hypergeometric distribution.
#
# Let's break down the problem:
#
# - We have a total of 22 items (10 identical items and 12 distinct items).
# - We randomly select 25 objects out of 22 items.
# - We need to find the probability of having at least 3 pairs, where each pair consists of identical items.
#
# Since there are 10 identical items, the number of ways to choose 2 of these identical items is C(10, 2), where C(n, r) is the number of combinations of n items taken r at a time.
#
# We will consider the following possible cases:
#
# - Case 1: We have exactly 3 pairs of identical items.
# - Case 2: We have exactly 4 pairs of identical items or more.
#
# To calculate the probability, we will use the hypergeometric distribution, which is given by:
#
# P(X = k) = [C(n, k) x C(N - n, N - k - n)] / C(N, n)
#
# where:
# - N is the total number of items (22)
# - n is the number of items to be selected (25)
# - k is the number of distinct items of the pair (C(10, 2) for the first pair)
# - C(N, n) is the number of ways to select n items from N
#
# We will also use the fact that the probability of having more pairs of identical items is included in the probability of having fewer pairs of identical items.
#
# To simplify the calculation, let's first calculate the probability of having more than 25 identical items, which is 0, since it's not possible to select more than 25 items. Then we can use the inclusion-exclusion principle to find the probability of having at least 3 pairs of identical items.
#
# Let's consider Case 1: having exactly 3 pairs of identical items.
#
# We need to select 3 pairs of identical items, and 4 distinct items from 12 distinct items, which can be found by considering the number of combinations of selecting the items.
#
# We can use the combinatorial approach to find the number of ways to achieve this.
#
# We need to find the probability of having exactly 3 pairs of identical items and 4 distinct items, which can be calculated as:
#
# P(X = 3) = [C(10, 2)^3 x C(12, 4)] / C(22, 25)
#
# Now, let's consider Case 2: having exactly 4 pairs of identical items or more.
#
# For Case 2, we can use the complementary probability, i.e., we will calculate the probability of having less than 4 pairs of identical items and subtract it from 1.
#
# To achieve this, we can use the inclusion-exclusion principle.
#
# We will start by calculating the probability of having exactly 3 or fewer pairs of identical items, using the inclusion-exclusion principle to avoid double-counting terms.
#
# The total probability P will be:
#
# P = [1 - P(X < 3)]
#
# P(X < 3) is the probability of having less than 3 pairs of identical items, which can be calculated using the inclusion-exclusion principle:
#
# P(X < 3) = P(X = 0) + P(X = 1) + P(X = 2)
#
# For P(X = 0):
#
# P(X = 0) = [C(12, 25)] / C(22, 25)
#
# For P(X = 1):
#
# P(X = 1) = [C(10, 2) x C(12, 23)] / C(22, 25)
#
# For P(X = 2):
#
# P(X = 2) = [C(10, 2)^2 x C(12, 21)] / C(22, 25)
#
# Now, let's put it all together.
#
# Let P = probability of having at least 3 pairs of identical items.
#
# We will use a calculator or any programming language to evaluate the expressions.
#
# After performing the necessary computations, using the combinatorial approach and the inclusion-exclusion principle, we will obtain a non-repeating, non-terminating decimal as the answer.
#
# The probability of finding at least 3 pairs of objects is approximately:
#
# P ≈ 0.0189
