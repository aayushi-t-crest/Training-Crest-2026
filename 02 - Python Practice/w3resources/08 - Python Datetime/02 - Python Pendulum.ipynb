# %% [markdown]
# #### **TimeZone Support**

# %%
import pendulum

germany_datetime = pendulum.now('Europe/Berlin')

print("Pendulum object for the current date and time in London timezone:", germany_datetime)
# Out:
# Pendulum object for the current date and time in London timezone: 2026-01-16 07:28:56.531078+01:00

# %%
india_datetime = pendulum.now('Asia/Kolkata')

# %%
print('Current timezone in india:', india_datetime)
# Out:
# Current timezone in india: 2026-01-16 11:59:36.329364+05:30

# %% [markdown]
# #### **Difference in Days**

# %%
date_str1 = "2018-03-15"
date_str2 = "2018-04-20"

# %%
date1 = pendulum.parse(date_str1)
date2 = pendulum.parse(date_str2)

days_difference = date2.diff(date1).in_days()

print(f"Difference in days: {days_difference} days")
# Out:
# Difference in days: 36 days

# %% [markdown]
# ## 3. Add and Subtract Duration:
#
# Write a Python program to add 3 hours and 30 minutes to the current date and time, then subtract 1 day using Pendulum module.

# %%
import pendulum

current_datetime = pendulum.now()

new_datetime = current_datetime.add(hours=3, minutes=30)

result_datetime = new_datetime.subtract(days=1)

print("Current Date and Time:", current_datetime)
print("After adding 3 hours and 30 minutes:", new_datetime)
print("After subtracting 1 day:", result_datetime)
# Out:
# Current Date and Time: 2026-01-16 12:01:17.983812+05:30
# After adding 3 hours and 30 minutes: 2026-01-16 15:31:17.983812+05:30
# After subtracting 1 day: 2026-01-15 15:31:17.983812+05:30
