# %% [markdown]
# ## 1. List Directories and Files
#
# Write a Python program to list only directories, files and all directories, files in a specified path.

# %%
import os
path = 'C:\\Users\\AayushiTrivedi\\Documents\\Crest Training\\Python Practice\\w3resources\\10 - Advanced Python Datatypes'
print("Only directories:")
print([ name for name in os.listdir(path) if os.path.isdir(os.path.join(path, name)) ])

print("\nOnly files:")
print([ name for name in os.listdir(path) if not os.path.isdir(os.path.join(path, name)) ])

print("\nAll directories and files :")
print([ name for name in os.listdir(path)])
# Out:
# Only directories:
# ['.ipynb_checkpoints']
#
# Only files:
# ['01 - Boolean Data Types.ipynb', '02 - None Data Types.ipynb', '03 - Bytes and Byte.ipynb', '04 - Python Memory views.ipynb', '05 - Frozenset Exercise.ipynb', '06 - NamedTuple Exercise.ipynb', '07 - Ordered Dict.ipynb', '08 - Python Counter.ipynb', '09 - Ellipsis.ipynb']
#
# All directories and files :
# ['.ipynb_checkpoints', '01 - Boolean Data Types.ipynb', '02 - None Data Types.ipynb', '03 - Bytes and Byte.ipynb', '04 - Python Memory views.ipynb', '05 - Frozenset Exercise.ipynb', '06 - NamedTuple Exercise.ipynb', '07 - Ordered Dict.ipynb', '08 - Python Counter.ipynb', '09 - Ellipsis.ipynb']

# %%
import os
import platform

print("Operating System:", os.name) 
print("\nInformation of current operating system: ", platform.uname())
print("\nCurrent Working Directory: ", os.getcwd())
print("\nList of files and directories in the current directory:")
print(os.listdir('.'))
# Out:
# Operating System: nt
#
# Information of current operating system:  uname_result(system='Windows', node='AayushiTrivedi', release='10', version='10.0.26100', machine='AMD64')
#
# Current Working Directory:  C:\Users\AayushiTrivedi\Documents\Crest Training\Python Practice\w3resources\12 - Python Modules
#
# List of files and directories in the current directory:
# ['.ipynb_checkpoints', '01 - Built-in Modules.ipynb', '02 - Python Os Services.ipynb', '03 - Math.ipynb', '04 - Requests.ipynb', '05 - SQLite Database.ipynb', 'example.db', 'temp.db']

# %%
print("\nTest if a specified file exists or not:")
filename = 'abc.txt'
try:
    with open(filename, 'r') as f:
        text = f.read()
        print("File content:")
        print(text)
except IOError:
    print('Not accessed or problem in reading: ' + filename)
# Out:
# Test if a specified file exists or not:
# Not accessed or problem in reading: abc.txt
