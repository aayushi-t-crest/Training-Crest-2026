# %% [markdown]
# ## 1. Word Frequency Counter
#
# Write a Python program to count the frequency of words in a file.

# %%
from collections import Counter
def word_count(fname):
    with open(fname) as f:
        return Counter(f.read().split())

print("Numbers of words in the file:" , word_count("test.txt"))
# Out:
# Numbers of words in the file: Counter({'is': 3, 'and': 3, 'Python': 2, 'the': 2, 'in': 2, 'development,': 2, 'for': 2, 'to': 2, 'one': 1, 'of': 1, 'most': 1, 'popular': 1, 'programming': 1, 'languages': 1, 'world': 1, 'today.': 1, 'It': 1, 'widely': 1, 'used': 1, 'software': 1, 'data': 1, 'science,': 1, 'artificial': 1, 'intelligence,': 1, 'machine': 1, 'learning,': 1, 'web': 1, 'automation,': 1, 'scientific': 1, 'computing.': 1, 'known': 1, 'its': 1, 'simple': 1, 'syntax': 1, 'readability,': 1, 'which': 1, 'makes': 1, 'it': 1, 'easy': 1, 'beginners': 1, 'learn': 1, 'professionals': 1, 'use': 1, 'efficiently.': 1})

# %% [markdown]
# ## 2. Count Words in File
#
# Write a Python program that takes a text file as input and returns the number of words of a given text file.

# %%
def count_words(filepath):
   with open(filepath) as f:
       data = f.read()
       data.replace(",", " ")
       return len(data.split(" "))

       
print(count_words("test.txt"))
# Out:
# 54
