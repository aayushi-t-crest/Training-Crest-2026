# %% [markdown]
# # Streaming

# %%
pip show langchain
# Out:
# Name: langchain
# Version: 1.2.10
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq

# %%
chat_template = ChatPromptTemplate.from_messages([
    ('human', 
     "I've recently adopted a {pet} which is a {breed}. Could you suggest several training tips?")])

# %%
chat = ChatGroq(model_name =  "llama-3.1-8b-instant", 
                  model_kwargs = {'seed':365},
                  temperature = 0,
                  max_tokens = 200)

# %%
chain = chat_template | chat

# %%
chain.invoke({'pet':'dog', 'breed':'shepherd'})
# Out:
# AIMessage(content='Congratulations on adopting a shepherd dog. Shepherds are highly intelligent and energetic breeds that require consistent training and socialization. Here are some training tips to help you get started:\n\n1. **Establish a routine**: Shepherds thrive on routine, so create a schedule for feeding, exercise, and training. This will help them feel secure and develop good habits.\n2. **Use positive reinforcement**: Reward your dog with treats, praise, and affection when they perform a desired behavior. Avoid punishment or negative reinforcement, as this can lead to fear and anxiety.\n3. **Start with basic obedience**: Teach your dog basic commands like "sit," "stay," "come," and "leave it." Use short, consistent training sessions and gradually increase the duration and difficulty.\n4. **Socialization is key**: Shepherds can be wary of strangers and other animals, so socialize your dog extensively. Take them to dog parks, puppy classes, and on walks around the neighborhood.\n5. **Exercise', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 200, 'prompt_tokens': 53, 'total_tokens': 253, 'completion_time': 0.235920027, 'completion_tokens_details': None, 'prompt_time': 0.00259001, 'prompt_tokens_details': None, 'queue_time': 0.04615413, 'total_time': 0.238510037}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c8e70-6b19-7021-81de-2b99382d8230-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 200, 'total_tokens': 253})

# %%
# %%time
chain.batch([{'pet':'dog', 'breed':'shepherd'}, 
             {'pet':'dragon', 'breed':'night fury'}])
# Out:
# CPU times: total: 31.2 ms
# Wall time: 420 ms
# [AIMessage(content='Congratulations on adopting a shepherd dog. Shepherds are highly intelligent and energetic breeds that require consistent training and socialization. Here are some training tips to help you get started:\n\n1. **Establish a routine**: Shepherds thrive on routine, so create a schedule for feeding, exercise, and training. This will help them feel secure and develop good habits.\n2. **Use positive reinforcement**: Reward your dog with treats, praise, and affection when they perform a desired behavior. Avoid punishment or negative reinforcement, as this can lead to fear and anxiety.\n3. **Start with basic obedience**: Teach your dog basic commands like "sit," "stay," "come," and "leave it." Use short, consistent training sessions and gradually increase the duration and difficulty.\n4. **Socialization is key**: Shepherds can be wary of strangers and other animals, so socialize your dog extensively. Take them to dog parks, puppy classes, and on walks around the neighborhood.\n5. **Exercise', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 200, 'prompt_tokens': 53, 'total_tokens': 253, 'completion_time': 0.235860286, 'completion_tokens_details': None, 'prompt_time': 0.002570705, 'prompt_tokens_details': None, 'queue_time': 0.045293105, 'total_time': 0.238430991}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c8e70-7084-7150-9f8d-5a1949616b74-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 200, 'total_tokens': 253}),
#  AIMessage(content='Congratulations on adopting a Night Fury dragon. They are intelligent, loyal, and powerful creatures. Here are some training tips to help you and your Night Fury develop a strong bond and master its abilities:\n\n1. **Establish Trust**: Night Furies are naturally wary of humans, so it\'s essential to build trust slowly. Start by offering treats and letting your dragon get accustomed to your presence. Gradually increase interaction time, and be patient with the process.\n2. **Use Positive Reinforcement**: Reward your Night Fury with treats, praise, and affection when it performs desired behaviors. This encourages good habits and strengthens your bond.\n3. **Teach Basic Commands**: Begin with simple commands like "sit," "stay," and "come." Use a consistent tone and hand signal to avoid confusion. As your dragon becomes more confident, you can introduce more complex commands.\n4. **Practice Flight Training**: Night Furies are agile and fast flyers. Start with short flights in a controlled environment, gradually increasing distance', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 200, 'prompt_tokens': 54, 'total_tokens': 254, 'completion_time': 0.266905384, 'completion_tokens_details': None, 'prompt_time': 0.003388664, 'prompt_tokens_details': None, 'queue_time': 0.046089216, 'total_time': 0.270294048}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c8e70-7088-75e3-98ca-0ade195fe665-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 54, 'output_tokens': 200, 'total_tokens': 254})]

# %%
response = chain.stream({'pet':'dragon', 'breed':'night fury'})

# %%
next(response)
# Out:
# AIMessageChunk(content='', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019c8e70-86a0-7612-bf68-5a6c5e2f8718', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])

# %%
for i in response:
    print(i.content, end = '')
# Out:
# Congratulations on adopting a Night Fury dragon. They are intelligent, loyal, and powerful creatures. Here are some training tips to help you and your Night Fury develop a strong bond and master its abilities:
#
# 1. **Establish Trust**: Night Furies are naturally wary of humans, so it's essential to build trust slowly. Start by offering treats and letting your dragon get accustomed to your presence. Gradually increase interaction time, and be patient with the process.
# 2. **Use Positive Reinforcement**: Reward your Night Fury with treats, praise, and affection when it performs desired behaviors. This encourages good habits and strengthens your bond.
# 3. **Teach Basic Commands**: Begin with simple commands like "sit," "stay," and "come." Use a consistent tone and hand signal to avoid confusion. As your dragon becomes more confident, you can introduce more complex commands.
# 4. **Practice Flight Training**: Night Furies are agile and fast flyers. Start with short flights in a controlled environment, gradually increasing distance
