# %% [markdown]
# # Batching

# %%
pip show langchain
# Out:
# Name: langchain
# Version: 1.2.10
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq

# %%
chat_template = ChatPromptTemplate.from_messages([
    ('human', 
     "I've recently adopted a {pet} which is a {breed}. Could you suggest several training tips?")])

# %%
chat = ChatGroq(model_name = "llama-3.1-8b-instant", 
                  model_kwargs = {'seed':365},
                  temperature = 0,
                  max_tokens = 100)

# %%
chain = chat_template | chat

# %%
chain.invoke({'pet':'dog', 'breed':'shepherd'})
# Out:
# AIMessage(content='Congratulations on adopting a shepherd dog. Shepherds are highly intelligent and energetic breeds that require consistent training and socialization. Here are some training tips to help you get started:\n\n1. **Establish a routine**: Shepherds thrive on routine, so create a schedule for feeding, exercise, and training. This will help them feel secure and develop good habits.\n2. **Use positive reinforcement**: Reward your dog with treats, praise, and affection when they perform a desired behavior. Avoid punishment or negative', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 53, 'total_tokens': 153, 'completion_time': 0.108728119, 'completion_tokens_details': None, 'prompt_time': 0.00255991, 'prompt_tokens_details': None, 'queue_time': 0.045645216, 'total_time': 0.111288029}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c8e6c-5d83-7ff2-8de0-7822328f0356-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 100, 'total_tokens': 153})

# %%
# %%time
chain.batch([{'pet':'dog', 'breed':'shepherd'}, 
             {'pet':'dragon', 'breed':'night fury'}])
# Out:
# CPU times: total: 15.6 ms
# Wall time: 307 ms
# [AIMessage(content='Congratulations on adopting a shepherd dog. Shepherds are highly intelligent and energetic breeds that require consistent training and socialization. Here are some training tips to help you get started:\n\n1. **Establish a routine**: Shepherds thrive on routine, so create a schedule for feeding, exercise, and training. This will help them feel secure and develop good habits.\n2. **Use positive reinforcement**: Reward your dog with treats, praise, and affection when they perform a desired behavior. Avoid punishment or negative', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 53, 'total_tokens': 153, 'completion_time': 0.107435844, 'completion_tokens_details': None, 'prompt_time': 0.002885194, 'prompt_tokens_details': None, 'queue_time': 0.047093463, 'total_time': 0.110321038}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c8e6c-7d10-7fb2-a33e-1ef6b1e3de40-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 100, 'total_tokens': 153}),
#  AIMessage(content="Congratulations on adopting a Night Fury dragon. They are intelligent, loyal, and powerful creatures. Here are some training tips to help you and your Night Fury develop a strong bond and master its abilities:\n\n1. **Establish Trust**: Night Furies are naturally wary of humans, so it's essential to build trust slowly. Start by offering treats and letting your dragon get accustomed to your presence. Gradually increase interaction time, and be patient with the process.\n2. **Use Positive Reinforcement**: Reward your", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 54, 'total_tokens': 154, 'completion_time': 0.140571711, 'completion_tokens_details': None, 'prompt_time': 0.00261339, 'prompt_tokens_details': None, 'queue_time': 0.05162266, 'total_time': 0.143185101}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c8e6c-7d27-73e1-9aec-e1a5eda3002b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 54, 'output_tokens': 100, 'total_tokens': 154})]

# %%
# %%time
chain.invoke({'pet':'dog', 'breed':'shepherd'})
# Out:
# CPU times: total: 15.6 ms
# Wall time: 221 ms
# AIMessage(content='Congratulations on adopting a shepherd dog. Shepherds are highly intelligent and energetic breeds that require consistent training and socialization. Here are some training tips to help you get started:\n\n1. **Establish a routine**: Shepherds thrive on routine, so create a schedule for feeding, exercise, and training. This will help them feel secure and develop good habits.\n2. **Use positive reinforcement**: Reward your dog with treats, praise, and affection when they perform a desired behavior. Avoid punishment or negative', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 53, 'total_tokens': 153, 'completion_time': 0.106710982, 'completion_tokens_details': None, 'prompt_time': 0.002947354, 'prompt_tokens_details': None, 'queue_time': 0.045073652, 'total_time': 0.109658336}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c8e6c-9385-7eb2-ac09-b3b032c936ca-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 100, 'total_tokens': 153})

# %%
# %%time
chain.invoke({'pet':'dragon', 'breed':'night fury'})
# Out:
# CPU times: total: 0 ns
# Wall time: 249 ms
# AIMessage(content="Congratulations on adopting a Night Fury dragon. They are intelligent, loyal, and powerful creatures. Here are some training tips to help you and your Night Fury develop a strong bond and master its abilities:\n\n1. **Establish Trust**: Night Furies are naturally wary of humans, so it's essential to build trust slowly. Start by offering treats and letting your dragon get accustomed to your presence. Gradually increase interaction time, and be patient with the process.\n2. **Use Positive Reinforcement**: Reward your", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 54, 'total_tokens': 154, 'completion_time': 0.142665291, 'completion_tokens_details': None, 'prompt_time': 0.00256591, 'prompt_tokens_details': None, 'queue_time': 0.046167176, 'total_time': 0.145231201}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c8e6c-9fd8-7590-9cef-02ef1b6af6ab-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 54, 'output_tokens': 100, 'total_tokens': 154})
