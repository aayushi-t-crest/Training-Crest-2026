# %%
import importlib.metadata as md

for pkg in ["langchain", "langchain-openai", "openai", "httpx"]:
    try:
        print(f"{pkg:16s} {md.version(pkg)}")
    except md.PackageNotFoundError:
        print(f"{pkg:16s} NOT INSTALLED")
# Out:
# langchain        NOT INSTALLED
# langchain-openai NOT INSTALLED
# openai           2.21.0
# httpx            0.28.1

# %%
pip install langchain langchain-groq groq
# Out:
# Collecting langchain
#   Using cached langchain-1.2.10-py3-none-any.whl.metadata (5.7 kB)
# Collecting langchain-groq
#   Using cached langchain_groq-1.1.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: groq in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (1.0.0)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain)
#   Downloading langchain_core-1.2.15-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.1.0,>=1.0.8 (from langchain)
#   Using cached langgraph-1.0.9-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from langchain) (2.12.5)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached langsmith-0.7.6-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.8->langchain)
#   Using cached langgraph_checkpoint-4.0.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.8 (from langgraph<1.1.0,>=1.0.8->langchain)
#   Using cached langgraph_prebuilt-1.0.8-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.1.0,>=1.0.8->langchain)
#   Using cached langgraph_sdk-0.3.8-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.8->langchain)
#   Using cached xxhash-3.6.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain)
#   Downloading ormsgpack-1.12.2-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.28.1)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain)
#   Downloading orjson-3.11.7-cp311-cp311-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Collecting groq
#   Using cached groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from groq) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from groq) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\AayushiTrivedi\.conda\envs\langchain_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Using cached langchain-1.2.10-py3-none-any.whl (111 kB)
# Downloading langchain_core-1.2.15-py3-none-any.whl (502 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langgraph-1.0.9-py3-none-any.whl (158 kB)
# Using cached langgraph_checkpoint-4.0.0-py3-none-any.whl (46 kB)
# Using cached langgraph_prebuilt-1.0.8-py3-none-any.whl (35 kB)
# Using cached langgraph_sdk-0.3.8-py3-none-any.whl (90 kB)
# Using cached langsmith-0.7.6-py3-none-any.whl (325 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
# Using cached langchain_groq-1.1.2-py3-none-any.whl (19 kB)
# Using cached groq-0.37.1-py3-none-any.whl (137 kB)
# Downloading orjson-3.11.7-cp311-cp311-win_amd64.whl (124 kB)
# Downloading ormsgpack-1.12.2-cp311-cp311-win_amd64.whl (117 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached xxhash-3.6.0-cp311-cp311-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, tenacity, ormsgpack, orjson, jsonpatch, requests-toolbelt, langsmith, langgraph-sdk, groq, langchain-core, langgraph-checkpoint, langchain-groq, langgraph-prebuilt, langgraph, langchain
#
#    -- -------------------------------------  1/17 [xxhash]
#    ------- --------------------------------  3/17 [tenacity]
#    ------- --------------------------------  3/17 [tenacity]
#    ----------- ----------------------------  5/17 [orjson]
#    ---------------- -----------------------  7/17 [requests-toolbelt]
#    ---------------- -----------------------  7/17 [requests-toolbelt]
#    ---------------- -----------------------  7/17 [requests-toolbelt]
#    ---------------- -----------------------  7/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [langsmith]
#    ------------------ ---------------------  8/17 [langsmith]
#    ------------------ ---------------------  8/17 [langsmith]
#    ------------------ ---------------------  8/17 [langsmith]
#    ------------------ ---------------------  8/17 [langsmith]
#    ------------------ ---------------------  8/17 [langsmith]
#    ------------------ ---------------------  8/17 [langsmith]
#    ------------------ ---------------------  8/17 [langsmith]
#    ------------------ ---------------------  8/17 [langsmith]
#    ------------------ ---------------------  8/17 [langsmith]
#    ------------------ ---------------------  8/17 [langsmith]
#    --------------------- ------------------  9/17 [langgraph-sdk]
#    --------------------- ------------------  9/17 [langgraph-sdk]
#    --------------------- ------------------  9/17 [langgraph-sdk]
#    --------------------- ------------------  9/17 [langgraph-sdk]
#    --------------------- ------------------  9/17 [langgraph-sdk]
#    --------------------- ------------------  9/17 [langgraph-sdk]
#    --------------------- ------------------  9/17 [langgraph-sdk]
#    --------------------- ------------------  9/17 [langgraph-sdk]
#    --------------------- ------------------  9/17 [langgraph-sdk]
#   Attempting uninstall: groq
#    --------------------- ------------------  9/17 [langgraph-sdk]
#     Found existing installation: groq 1.0.0
#    --------------------- ------------------  9/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [groq]
#     Uninstalling groq-1.0.0:
#    ----------------------- ---------------- 10/17 [groq]
#       Successfully uninstalled groq-1.0.0
#    ----------------------- ---------------- 10/17 [groq]
#    ----------------------- ---------------- 10/17 [groq]
#    ----------------------- ---------------- 10/17 [groq]
#    ----------------------- ---------------- 10/17 [groq]
#    ----------------------- ---------------- 10/17 [groq]
#    ----------------------- ---------------- 10/17 [groq]
#    ----------------------- ---------------- 10/17 [groq]
#    ----------------------- ---------------- 10/17 [groq]
#    ----------------------- ---------------- 10/17 [groq]
#    ----------------------- ---------------- 10/17 [groq]
#    ----------------------- ---------------- 10/17 [groq]
#    ----------------------- ---------------- 10/17 [groq]
#    ----------------------- ---------------- 10/17 [groq]
#    ----------------------- ---------------- 10/17 [groq]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ---------------------------- ----------- 12/17 [langgraph-checkpoint]
#    ---------------------------- ----------- 12/17 [langgraph-checkpoint]
#    ------------------------------ --------- 13/17 [langchain-groq]
#    -------------------------------- ------- 14/17 [langgraph-prebuilt]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ---------------------------------------- 17/17 [langchain]
#
# Successfully installed groq-0.37.1 jsonpatch-1.33 langchain-1.2.10 langchain-core-1.2.15 langchain-groq-1.1.2 langgraph-1.0.9 langgraph-checkpoint-4.0.0 langgraph-prebuilt-1.0.8 langgraph-sdk-0.3.8 langsmith-0.7.6 orjson-3.11.7 ormsgpack-1.12.2 requests-toolbelt-1.0.0 tenacity-9.1.4 uuid-utils-0.14.1 xxhash-3.6.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import langchain
import groq
from langchain_groq import ChatGroq
import os

# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
chat = ChatGroq(
    model_name="llama-3.1-8b-instant",   # Correct Groq model name
    temperature=0,
    groq_api_key=os.getenv("GROQ_API_KEY")
)

# %%
prompt = "I've recently adopted a dog. Could you suggest some dog names?"

response = chat.invoke(prompt)

print(response.content)
# Out:
# Congratulations on adopting a new furry family member.  I'd be happy to help you find the perfect name for your dog. Here are some popular and unique name suggestions:
#
# **Male Dog Names:**
#
# 1. Max
# 2. Charlie
# 3. Buddy
# 4. Cooper
# 5. Rocky
# 6. Duke
# 7. Bear
# 8. Oliver
# 9. Finn
# 10. Jasper
# 11. Archie
# 12. Bentley
# 13. Hunter
# 14. Milo
# 15. Gus
#
# **Female Dog Names:**
#
# 1. Luna
# 2. Bella
# 3. Lucy
# 4. Daisy
# 5. Gracie
# 6. Sadie
# 7. Maggie
# 8. Abbie
# 9. Sophie
# 10. Zoe
# 11. Lola
# 12. Coco
# 13. Ginger
# 14. Fiona
# 15. Willow
#
# **Unique Dog Names:**
#
# 1. Aurora (for a dog with a celestial personality)
# 2. Sage (for a wise and intelligent dog)
# 3. Lyra (for a musical and playful dog)
# 4. Orion (for a bold and adventurous dog)
# 5. Piper (for a confident and charming dog)
# 6. Wren (for a small and energetic dog)
# 7. Caspian (for a majestic and powerful dog)
# 8. Remi (for a lively and affectionate dog)
# 9. Indigo (for a mysterious and creative dog)
# 10. Marlowe (for a clever and adventurous dog)
#
# **Consider Your Dog's Breed, Size, and Personality:**
#
# * If your dog is a large breed, consider names like Atlas, Titan, or Zeus.
# * If your dog is a small breed, consider names like Pixie, Lola, or Gidget.
# * If your dog is energetic and playful, consider names like Zoom, Flash, or Sparky.
# * If your dog is calm and gentle, consider names like Luna, Daisy, or Gracie.
#
# Remember, the most important thing is to choose a name that you and your dog will love and enjoy using.
